# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
from scipy import stats
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

print(cities)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# ['chagda', 'chuy', 'namibe', 'hilo', 'cabo san lucas', 'vaini', 'punta arenas', 'padang', 'kruisfontein', 'bonfim', 'chokurdakh', 'woodward', 'hobart', 'cape town', 'urumqi', 'albany', 'hermanus', 'leninsk', 'kapaa', 'arinos', 'georgetown', 'ushuaia', 'aksarka', 'saint-philippe', 'bethel', 'rikitea', 'puerto ayora', 'tiksi', 'half moon bay', 'adre', 'longyearbyen', 'atuona', 'vila do maio', 'lavrentiya', 'hithadhoo', 'porto novo', 'bredasdorp', 'illoqqortoormiut', 'cayenne', 'butterworth', 'miri', 'itarema', 'tasiilaq', 'nanortalik', 'bluff', 'harper', 'taolanaro', 'granville', 'wagga wagga', 'damietta', 'belmonte', 'tarauaca', 'oskarshamn', 'kaitangata', 'galitsy', 'mahebourg', 'cherskiy', 'keti bandar', 'bengkulu', 'samusu', 'aykhal', 'avarua', 'baker city', 'king city', 'kahului', 'attawapiskat', 'bandundu', 'labutta', 'castro', 'lewistown', 'portland', 'mataura', 'bambanglipuro', 'daru', 'tsihombe', 'korla', 'lerwick', 'palabuhanratu', 'port alfred', 'udachnyy', 'beitbridge', 'qaanaaq', 'eyl', 'yar-sale', 'abu dhabi', 'luena', 'kodiak', 'victoria', 'san quintin', 'mys shmidta', 'butaritari', 'iberia', 'necochea', 'sao joao da barra', 'grand river south east', 'agua dulce', 'liverpool', 'sorong', 'asau', 'dwarka', 'ancud', 'sambava', 'ossora', 'paamiut', 'kutum', 'pisco', 'ulladulla', 'tuktoyaktuk', 'lorengau', 'maniitsoq', 'belushya guba', 'mount isa', 'klaksvik', 'kiama', 'east london', 'alta floresta', 'najran', 'rio gallegos', 'sharya', 'yellowknife', 'busselton', 'college', 'vila franca do campo', 'bambous virieux', 'gurskoye', 'langsa', 'san patricio', 'iqaluit', 'buta', 'zhezkazgan', 'masterton', 'burlington', 'santa cruz de tenerife', 'hammerfest', 'fort nelson', 'barrow', 'labuhan', 'san carlos', 'diapaga', 'sol-iletsk', 'lebu', 'antibes', 'howard springs', 'leh', 'khandyga', 'esperance', 'inhambane', 'adrar', 'ambon', 'los llanos de aridane', 'saleaula', 'nikolskoye', 'palembang', 'jamestown', 'baracoa', 'liaoyang', 'vardo', 'along', 'bozuyuk', 'markova', 'praia da vitoria', 'temaraia', 'talaya', 'barentsburg', 'acari', 'cidreira', 'ponta do sol', 'vestmannaeyjar', 'warqla', 'khatanga', 'port augusta', 'constantine', 'tumannyy', 'new norfolk', 'nyagan', 'boguchany', 'chiredzi', 'paciran', 'rio grande', 'teahupoo', 'louisbourg', 'civita castellana', 'chapada dos guimaraes', 'dali', 'san juan de uraba', 'ballina', 'otane', 'talnakh', 'beyneu', 'marica', 'mount gambier', 'hajdudorog', 'kavieng', 'asnaes', 'acu', 'mantua', 'gabu', 'lagoa', 'hovd', 'walvis bay', 'narsaq', 'kamaishi', 'derzhavinsk', 'anadyr', 'dikson', 'tuy hoa', 'thompson', 'shumskiy', 'port hardy', 'lincoln', 'cap malheureux', 'vila velha', 'tarko-sale', 'omsukchan', 'kununurra', 'chesma', 'pauri', 'solwezi', 'leningradskiy', 'severo-kurilsk', 'qabis', 'sahuaripa', 'sao filipe', 'koulikoro', 'manokwari', 'sao jose da coroa grande', 'pasni', 'dire dawa', 'ribeira grande', 'klobuck', 'kisangani', 'mar del plata', 'hasaki', 'manta', 'ocean springs', 'kano', 'hokitika', 'jieshi', 'itoman', 'faanui', 'murud', 'shingu', 'longford', 'esqueda', 'ushtobe', 'katsuura', 'sola', 'jalu', 'lompoc', 'upernavik', 'rawson', 'oriximina', 'suntar', 'solnechnyy', 'znamenskoye', 'lasa', 'sechura', 'fort saint james', 'saint george', 'kieta', 'manggar', 'zafra', 'general pico', 'piuma', 'bialogard', 'srinagar', 'port lincoln', 'arraial do cabo', 'leua', 'coalcoman', 'khorixas', 'stettler', 'san rafael', 'rovaniemi', 'marawi', 'gat', 'magaria', 'saskylakh', 'biak', 'sisimiut', 'eureka', 'kavalerovo', 'lahad datu', 'mehran', 'beringovskiy', 'bonga', 'vanimo', 'fortuna', 'chumphon', 'banff', 'kutahya', 'addi ugri', 'palmer', 'olafsvik', 'boyolangu', 'bingol', 'kulebaki', 'krasnovishersk', 'antsohihy', 'grindavik', 'bichura', 'trairi', 'hongan', 'yarada', 'blankenberge', 'west odessa', 'puerto narino', 'kunzelsau', 'codrington', 'kedrovyy', 'krasnoselkup', 'bousso', 'fare', 'virginia beach', 'bardiyah', 'karaul', 'puerto el triunfo', 'komsomolskiy', 'bukachacha', 'muhos', 'loi ...
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# create list to hold data
name = []
lat = []
lon = []
temp_max = []
humidity = []
clouds = []
speed = []
country = []
dt = []

counter = 0

# loop through cities to get weather data
for city in cities:
    
    counter += 1
    
    try:   
        # get weather data
        response = requests.get(query_url + city).json()
        name.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        dt.append(response['dt'])
        
        print(f"Processing Record {counter} | The city name is {city}")
    
    except:
        print(f"City not found: {city}  Skipping ...")
# Out:
# City not found: chagda  Skipping ...
# Processing Record 2 | The city name is chuy
# Processing Record 3 | The city name is namibe
# Processing Record 4 | The city name is hilo
# Processing Record 5 | The city name is cabo san lucas
# Processing Record 6 | The city name is vaini
# Processing Record 7 | The city name is punta arenas
# Processing Record 8 | The city name is padang
# Processing Record 9 | The city name is kruisfontein
# Processing Record 10 | The city name is bonfim
# Processing Record 11 | The city name is chokurdakh
# Processing Record 12 | The city name is woodward
# Processing Record 13 | The city name is hobart
# Processing Record 14 | The city name is cape town
# Processing Record 15 | The city name is urumqi
# Processing Record 16 | The city name is albany
# Processing Record 17 | The city name is hermanus
# Processing Record 18 | The city name is leninsk
# Processing Record 19 | The city name is kapaa
# Processing Record 20 | The city name is arinos
# Processing Record 21 | The city name is georgetown
# Processing Record 22 | The city name is ushuaia
# Processing Record 23 | The city name is aksarka
# Processing Record 24 | The city name is saint-philippe
# Processing Record 25 | The city name is bethel
# Processing Record 26 | The city name is rikitea
# Processing Record 27 | The city name is puerto ayora
# Processing Record 28 | The city name is tiksi
# Processing Record 29 | The city name is half moon bay
# Processing Record 30 | The city name is adre
# Processing Record 31 | The city name is longyearbyen
# Processing Record 32 | The city name is atuona
# Processing Record 33 | The city name is vila do maio
# Processing Record 34 | The city name is lavrentiya
# Processing Record 35 | The city name is hithadhoo
# Processing Record 36 | The city name is porto novo
# Processing Record 37 | The city name is bredasdorp
# City not found: illoqqortoormiut  Skipping ...
# Processing Record 39 | The city name is cayenne
# Processing Record 40 | The city name is butterworth
# Processing Record 41 | The city name is miri
# Processing Record 42 | The city name is itarema
# Processing Record 43 | The city name is tasiilaq
# Processing Record 44 | The city name is nanortalik
# Processing Record 45 | The city name is bluff
# Processing Record 46 | The city name is harper
# City not found: taolanaro  Skipping ...
# Processing Record 48 | The city name is granville
# Processing Record 49 | The city name is wagga wagga
# Processing Record 50 | The city name is damietta
# Processing Record 51 | The city name is belmonte
# Processing Record 52 | The city name is tarauaca
# Processing Record 53 | The city name is oskarshamn
# Processing Record 54 | The city name is kaitangata
# Processing Record 55 | The city name is galitsy
# Processing Record 56 | The city name is mahebourg
# Processing Record 57 | The city name is cherskiy
# Processing Record 58 | The city name is keti bandar
# Processing Record 59 | The city name is bengkulu
# City not found: samusu  Skipping ...
# Processing Record 61 | The city name is aykhal
# Processing Record 62 | The city name is avarua
# Processing Record 63 | The city name is baker city
# Processing Record 64 | The city name is king city
# Processing Record 65 | The city name is kahului
# City not found: attawapiskat  Skipping ...
# Processing Record 67 | The city name is bandundu
# City not found: labutta  Skipping ...
# Processing Record 69 | The city name is castro
# Processing Record 70 | The city name is lewistown
# Processing Record 71 | The city name is portland
# Processing Record 72 | The city name is mataura
# Processing Record 73 | The city name is bambanglipuro
# Processing Record 74 | The city name is daru
# City not found: tsihombe  Skipping ...
# Processing Record 76 | The city name is korla
# Processing Record 77 | The city name is lerwick
# City not found: palabuhanratu  Skipping ...
# Processing Record 79 | The city name is port alfred
# Processing Record 80 | The city name is udachnyy
# Processing Record 81 | The city name is beitbridge
# Processing Record 82 | The city name is qaanaaq
# Processing Record 83 | The city name is eyl
# Processing Record 84 | The city name is yar-sale
# Processing Record 85 | The city name is abu dhabi
# Processing Record 86 | The city name is luena
# Processing Record 87 | The city name is kodiak
# Processing Record 88 | The city name is victoria
# Processing Record 89 | The city name is san quintin
# City not found: mys shmidta  Skipping ...
# Processing Record 91 | The city name is butaritari
# Processing Record 92 | The city name is iberia
# Processing Record 93 | The city name is necochea
# Processing Record 94 | The city name is sao joao da barra
# City not found: grand river south east  Skipping ...
# Processing Record 96 | The city name is agua dulce
# Processing Record 97 | The city name is liverpool
# Processing Record 98 | The city name is sorong
# Processing Record 99 | The city name is asau
# Processing Record 100 | The city name is dwarka
# Processing Record 101 | The city name is ancud
# Processing Record 102 | The city name is sambava
# Processing Record 103 | The city name is ossora
# Processing Record 104 | The city name is paamiut
# Processing Record 105 | The city name is kutum
# Processing Record 106 | The city name is pisco
# Processing Record 107 | The city name is ulladulla
# Processing Record 108 | The city name is tuktoyaktuk
# Processing Record 109 | The city name is lorengau
# Processing Record 110 | The city name is maniitsoq
# City not found: belushya guba  Skipping ...
# Processing Record 112 | The city name is mount isa
# Processing Record 113 | The city name is klaksvik
# Processing Record 114 | The city name is kiama
# Processing Record 115 | The city name is east london
# Processing Record 116 | The city name is alta floresta
# Processing Record 117 | The city name is najran
# Processing Record 118 | The city name is rio gallegos
# Processing Record 119 | The city name is sharya
# Processing Record 120 | The city name is yellowknife
# Processing Record 121 | The city name is busselton
# Processing Record 122 | The city name is college
# Processing Record 123 | The city name is vila franca do campo
# Processing Record 124 | The city name is bambous virieux
# City not found: gurskoye  Skipping ...
# Processing Record 126 | The city name is langsa
# Processing Record 127 | The city name is san patricio
# Processing Record 128 | The city name is iqaluit
# Processing Record 129 | The city name is buta
# Processing Record 130 | The city name is zhezkazgan
# Processing Record 131 | The city name is masterton
# Processing Record 132 | The city name is burlington
# Processing Record 133 | The city name is santa cruz de tenerife
# Processing Record 134 | The city name is hammerfest
# Processing Record 135 | The city name is fort nelson
# Processing Record 136 | The city name is barrow
# Processing Record 137 | The city name is labuhan
# Processing Record 138 | The city name is san carlos
# Processing Record 139 | The city name is diapaga
# Processing Record 140 | The city name is sol-iletsk
# Processing Record 141 | The city name is lebu
# Processing Record 142 | The city name is antibes
# Processing Record 143 | The city name is howard springs
# Processing Record 144 | The city name is leh
# Processing Record 145 | The city name is khandyga
# Processing Record 146 | The city name is esperance
# Processing Record 147 | The city name is inhambane
# Processing Record 148 | The city name is adrar
# Processing Record 149 | The city name is ambon
# Processing Record 150 | The city name is los llanos de aridane
# City not found: saleaula  Skipping ...
# Processing Record 152 | The city name is nikolskoye
# Processing Record 153 | The city name is palembang
# Processing Record 154 | The city name is jamestown
# Processing Record 155 | The city name is baracoa
# Processing Record 156 | The city name is liaoyang
# Processing Record 157 | The city name is vardo
# Processing Record 158 | The city name is along
# Processing Record 159 | The city name is bozuyuk
# Processing Record 160 | The city name is markova
# Processing Record 161 | The city name is praia da vitoria
# City not found: temaraia  Skipping ...
# Processing Record 163 | The city name is talaya
# City not found: barentsburg  Skipping ...
# Processing Record 165 | The city name is acari
# Processing Record 166 | The city name is cidreira
# Processing Record 167 | The city name is ponta do sol
# Processing Record 168 | The city name is vestmannaeyjar
# City not found: warqla  Skipping ...
# Processing Record 170 | The city name is khatanga
# Processing Record 171 | The city name is port augusta
# Processing Record 172 | The city name is constantine
# City not found: tumannyy  Skipping ...
# Processing Record 174 | The city name is new norfolk
# Processing Record 175 | The city name is nyagan
# Processing Record 176 | The city name is boguchany
# Processing Record 177 | The city name is chiredzi
# Processing Record 178 | The city name is paciran
# Processing Record 179 | The city name is rio grande
# Processing Record 180 | The city name is teahupoo
# City not found: louisbourg  Skipping ...
# Processing Record 182 | The city name is civita castellana
# Processing Record 183 | The city name is chapada dos guimaraes
# Processing Record 184 | The city name is dali
# Processing Record 185 | The city name is san juan de uraba
# Processing Record 186 | The city name is ballina
# Processing Record 187 | The city name is otane
# Processing Record 188 | The city name is talnakh
# Processing Record 189 | The city name is beyneu
# Processing Record 190 | The city name is marica
# Processing Record 191 | The city name is mount gambier
# Processing Record 192 | The city name is hajdudorog
# Processing Record 193 | The city name is kavieng
# Processing Record 194 | The city name is asnaes
# Processing Record 195 | The city name is acu
# Processing Record 196 | The city name is mantua
# Processing Record 197 | The city name is gabu
# Processing Record 198 | The city name is lagoa
# Processing Record 199 | The city name is hovd
# Processing Record 200 | The city name is walvis bay
# Processing Record 201 | The city name is narsaq
# Processing Record 202 | The city name is kamaishi
# Processing Record 203 | The city name is derzhavinsk
# Processing Record 204 | The city name is anadyr
# Processing Record 205 | The city name is dikson
# Processing Record 206 | The city name is tuy hoa
# Processing Record 207 | The city name is thompson
# Processing Record 208 | The city name is shumskiy
# Processing Record 209 | The city name is port hardy
# Processing Record 210 | The city name is lincoln
# Processing Record 211 | The city name is cap malheureux
# Processing Record 212 | The city name is vila velha
# Processing Record 213 | The city name is tarko-sale
# Processing Record 214 | The city name is omsukchan
# Processing Record 215 | The city name is kununurra
# Processing Record 216 | The city name is chesma
# Processing Record 217 | The city name is pauri
# Processing Record 218 | The city name is solwezi
# Processing Record 219 | The city name is leningradskiy
# Processing Record 220 | The city name is severo-kurilsk
# City not found: qabis  Skipping ...
# Processing Record 222 | The city name is sahuaripa
# Processing Record 223 | The city name is sao filipe
# Processing Record 224 | The city name is koulikoro
# Processing Record 225 | The city name is manokwari
# Processing Record 226 | The city name is sao jose da coroa grande
# Processing Record 227 | The city name is pasni
# Processing Record 228 | The city name is dire dawa
# Processing Record 229 | The city name is ribeira grande
# Processing Record 230 | The city name is klobuck
# Processing Record 231 | The city name is kisangani
# Processing Record 232 | The city name is mar del plata
# Processing Record 233 | The city name is hasaki
# Processing Record 234 | The city name is manta
# Processing Record 235 | The city name is ocean springs
# Processing Record 236 | The city name is kano
# Processing Record 237 | The city name is hokitika
# Processing Record 238 | The city name is jieshi
# Processing Record 239 | The city name is itoman
# Processing Record 240 | The city name is faanui
# Processing Record 241 | The city name is murud
# Processing Record 242 | The city name is shingu
# Processing Record 243 | The city name is longford
# Processing Record 244 | The city name is esqueda
# Processing Record 245 | The city name is ushtobe
# Processing Record 246 | The city name is katsuura
# Processing Record 247 | The city name is sola
# Processing Record 248 | The city name is jalu
# Processing Record 249 | The city name is lompoc
# Processing Record 250 | The city name is upernavik
# Processing Record 251 | The city name is rawson
# Processing Record 252 | The city name is oriximina
# Processing Record 253 | The city name is suntar
# Processing Record 254 | The city name is solnechnyy
# Processing Record 255 | The city name is znamenskoye
# Processing Record 256 | The city name is lasa
# Processing Record 257 | The city name is sechura
# Processing Record 258 | The city name is fort saint james
# Processing Record 259 | The city name is saint george
# Processing Record 260 | The city name is kieta
# Processing Record 261 | The city name is manggar
# Processing Record 262 | The city name is zafra
# Processing Record 263 | The city name is general pico
# Processing Record 264 | The city name is piuma
# Processing Record 265 | The city name is bialogard
# Processing Record 266 | The city name is srinagar
# Processing Record 267 | The city name is port lincoln
# Processing Record 268 | The city name is arraial do cabo
# Processing Record 269 | The city name is leua
# City not found: coalcoman  Skipping ...
# Processing Record 271 | The city name is khorixas
# Processing Record 272 | The city name is stettler
# Processing Record 273 | The city name is san rafael
# Processing Record 274 | The city name is rovaniemi
# Processing Record 275 | The city name is marawi
# Processing Record 276 | The city name is gat
# Processing Record 277 | The city name is magaria
# Processing Record 278 | The city name is saskylakh
# Processing Record 279 | The city name is biak
# Processing Record 280 | The city name is sisimiut
# Processing Record 281 | The city name is eureka
# Processing Record 282 | The city name is kavalerovo
# Processing Record 283 | The city name is lahad datu
# Processing Record 284 | The city name is mehran
# Processing Record 285 | The city name is beringovskiy
# Processing Record 286 | The city name is bonga
# Processing Record 287 | The city name is vanimo
# Processing Record 288 | The city name is fortuna
# Processing Record 289 | The city name is chumphon
# Processing Record 290 | The city name is banff
# Processing Record 291 | The city name is kutahya
# City not found: addi ugri  Skipping ...
# Processing Record 293 | The city name is palmer
# Processing Record 294 | The city name is olafsvik
# Processing Record 295 | The city name is boyolangu
# Processing Record 296 | The city name is bingol
# Processing Record 297 | The city name is kulebaki
# Processing Record 298 | The city name is krasnovishersk
# Processing Record 299 | The city name is antsohihy
# Processing Record 300 | The city name is grindavik
# Processing Record 301 | The city name is bichura
# Processing Record 302 | The city name is trairi
# City not found: hongan  Skipping ...
# Processing Record 304 | The city name is yarada
# Processing Record 305 | The city name is blankenberge
# Processing Record 306 | The city name is west odessa
# Processing Record 307 | The city name is puerto narino
# Processing Record 308 | The city name is kunzelsau
# Processing Record 309 | The city name is codrington
# Processing Record 310 | The city name is kedrovyy
# Processing Record 311 | The city name is krasnoselkup
# Processing Record 312 | The city name is bousso
# Processing Record 313 | The city name is fare
# Processing Record 314 | The city name is virginia beach
# Processing Record 315 | The city name is bardiyah
# City not found: karaul  Skipping ...
# Processing Record 317 | The city name is puerto el triunfo
# Processing Record 318 | The city name is komsomolskiy
# Processing Record 319 | The city name is bukachacha
# Processing Record 320 | The city name is muhos
# Processing Record 321 | The city name is loiza
# Processing Record 322 | The city name is muros
# Processing Record 323 | The city name is salalah
# Processing Record 324 | The city name is vanavara
# Processing Record 325 | The city name is pitsunda
# Processing Record 326 | The city name is mago
# Processing Record 327 | The city name is buchanan
# Processing Record 328 | The city name is yatou
# Processing Record 329 | The city name is bucerias
# Processing Record 330 | The city name is grand forks
# Processing Record 331 | The city name is bageshwar
# Processing Record 332 | The city name is vao
# Processing Record 333 | The city name is kochkurovo
# Processing Record 334 | The city name is duku
# Processing Record 335 | The city name is bulgan
# Processing Record 336 | The city name is saint-francois
# Processing Record 337 | The city name is kinshasa
# Processing Record 338 | The city name is naze
# Processing Record 339 | The city name is moindou
# Processing Record 340 | The city name is cabedelo
# Processing Record 341 | The city name is nueva loja
# Processing Record 342 | The city name is dillon
# Processing Record 343 | The city name is morondava
# Processing Record 344 | The city name is akyab
# Processing Record 345 | The city name is carbonia
# Processing Record 346 | The city name is wawa
# Processing Record 347 | The city name is port elizabeth
# Processing Record 348 | The city name is gusau
# Processing Record 349 | The city name is souillac
# Processing Record 350 | The city name is vanderhoof
# Processing Record 351 | The city name is calama
# Processing Record 352 | The city name is shimoda
# Processing Record 353 | The city name is narasannapeta
# Processing Record 354 | The city name is ikwiriri
# Processing Record 355 | The city name is payson
# Processing Record 356 | The city name is hebi
# Processing Record 357 | The city name is imeni poliny osipenko
# Processing Record 358 | The city name is richards bay
# Processing Record 359 | The city name is pevek
# Processing Record 360 | The city name is iwanai
# Processing Record 361 | The city name is daliang
# Processing Record 362 | The city name is diu
# Processing Record 363 | The city name is constitucion
# Processing Record 364 | The city name is salinopolis
# Processing Record 365 | The city name is isla aguada
# Processing Record 366 | The city name is crossville
# Processing Record 367 | The city name is gigmoto
# Processing Record 368 | The city name is baiyin
# Processing Record 369 | The city name is hyeres
# City not found: vaitupu  Skipping ...
# Processing Record 371 | The city name is dharchula
# Processing Record 372 | The city name is litovko
# Processing Record 373 | The city name is la ronge
# Processing Record 374 | The city name is sitka
# Processing Record 375 | The city name is danilovka
# Processing Record 376 | The city name is tire
# Processing Record 377 | The city name is torbay
# City not found: umzimvubu  Skipping ...
# Processing Record 379 | The city name is skelleftea
# City not found: yanan  Skipping ...
# Processing Record 381 | The city name is carnarvon
# Processing Record 382 | The city name is karacakoy
# Processing Record 383 | The city name is geraldton
# City not found: sentyabrskiy  Skipping ...
# Processing Record 385 | The city name is angoche
# Processing Record 386 | The city name is cockburn town
# Processing Record 387 | The city name is tubuala
# City not found: sorvag  Skipping ...
# Processing Record 389 | The city name is borazjan
# Processing Record 390 | The city name is golden
# Processing Record 391 | The city name is sangar
# Processing Record 392 | The city name is kavaratti
# Processing Record 393 | The city name is sretensk
# Processing Record 394 | The city name is ulaangom
# Processing Record 395 | The city name is gushikawa
# Processing Record 396 | The city name is hazorasp
# Processing Record 397 | The city name is alice springs
# Processing Record 398 | The city name is provideniya
# Processing Record 399 | The city name is iranshahr
# Processing Record 400 | The city name is gambela
# Processing Record 401 | The city name is anahuac
# Processing Record 402 | The city name is la sarre
# Processing Record 403 | The city name is ilhabela
# Processing Record 404 | The city name is yichun
# Processing Record 405 | The city name is acapulco
# Processing Record 406 | The city name is biltine
# Processing Record 407 | The city name is yeppoon
# Processing Record 408 | The city name is omboue
# Processing Record 409 | The city name is almaznyy
# Processing Record 410 | The city name is port blair
# Processing Record 411 | The city name is tucuma
# Processing Record 412 | The city name is aswan
# City not found: toliary  Skipping ...
# Processing Record 414 | The city name is kumano
# Processing Record 415 | The city name is marsh harbour
# Processing Record 416 | The city name is kalengwa
# Processing Record 417 | The city name is stephenville
# Processing Record 418 | The city name is grushevskaya
# Processing Record 419 | The city name is gurupi
# Processing Record 420 | The city name is sao jose do belmonte
# City not found: viligili  Skipping ...
# Processing Record 422 | The city name is katherine
# Processing Record 423 | The city name is opotiki
# Processing Record 424 | The city name is bentiu
# Processing Record 425 | The city name is watsa
# Processing Record 426 | The city name is srednekolymsk
# Processing Record 427 | The city name is darhan
# Processing Record 428 | The city name is guerrero negro
# Processing Record 429 | The city name is aflao
# Processing Record 430 | The city name is rognan
# Processing Record 431 | The city name is taoudenni
# Processing Record 432 | The city name is abengourou
# Processing Record 433 | The city name is ornskoldsvik
# Processing Record 434 | The city name is stade
# Processing Record 435 | The city name is doha
# Processing Record 436 | The city name is san andres
# Processing Record 437 | The city name is kalmar
# Processing Record 438 | The city name is dustlik
# Processing Record 439 | The city name is kloulklubed
# Processing Record 440 | The city name is hun
# City not found: nizhneyansk  Skipping ...
# Processing Record 442 | The city name is prescott
# Processing Record 443 | The city name is verkhoyansk
# Processing Record 444 | The city name is batagay-alyta
# Processing Record 445 | The city name is zemetchino
# Processing Record 446 | The city name is mackay
# Processing Record 447 | The city name is ahipara
# Processing Record 448 | The city name is abancay
# Processing Record 449 | The city name is santa rosa
# Processing Record 450 | The city name is reghiu
# City not found: grand centre  Skipping ...
# Processing Record 452 | The city name is bantry
# Processing Record 453 | The city name is kaka
# Processing Record 454 | The city name is orotukan
# Processing Record 455 | The city name is palafrugell
# Processing Record 456 | The city name is maniwaki
# Processing Record 457 | The city name is dunedin
# Processing Record 458 | The city name is ilulissat
# Processing Record 459 | The city name is alofi
# Processing Record 460 | The city name is puerto escondido
# Processing Record 461 | The city name is lamu
# Processing Record 462 | The city name is joanopolis
# Processing Record 463 | The city name is khani
# City not found: halalo  Skipping ...
# Processing Record 465 | The city name is nowe miasto lubawskie
# City not found: amderma  Skipping ...
# Processing Record 467 | The city name is touros
# Processing Record 468 | The city name is rosarito
# Processing Record 469 | The city name is faya
# Processing Record 470 | The city name is camacha
# Processing Record 471 | The city name is panaba
# City not found: cagayan de tawi-tawi  Skipping ...
# Processing Record 473 | The city name is kunming
# Processing Record 474 | The city name is ponazyrevo
# Processing Record 475 | The city name is oshkosh
# Processing Record 476 | The city name is salta
# Processing Record 477 | The city name is san juan de las huertas
# Processing Record 478 | The city name is airai
# Processing Record 479 | The city name is isangel
# Processing Record 480 | The city name is qinhuangdao
# Processing Record 481 | The city name is nome
# Processing Record 482 | The city name is maceio
# Processing Record 483 | The city name is launceston
# Processing Record 484 | The city name is dordrecht
# Processing Record 485 | The city name is west fargo
# Processing Record 486 | The city name is ambato
# Processing Record 487 | The city name is viedma
# Processing Record 488 | The city name is kalas
# City not found: krasnoyarsk-66  Skipping ...
# Processing Record 490 | The city name is sarakhs
# Processing Record 491 | The city name is henties bay
# Processing Record 492 | The city name is inuvik
# Processing Record 493 | The city name is payo
# Processing Record 494 | The city name is altamont
# Processing Record 495 | The city name is uige
# City not found: cheuskiny  Skipping ...
# Processing Record 497 | The city name is comodoro rivadavia
# Processing Record 498 | The city name is kuching
# Processing Record 499 | The city name is phuket
# Processing Record 500 | The city name is umm lajj
# Processing Record 501 | The city name is poum
# Processing Record 502 | The city name is dingle
# Processing Record 503 | The city name is luderitz
# Processing Record 504 | The city name is coquimbo
# Processing Record 505 | The city name is bilibino
# Processing Record 506 | The city name is maraa
# Processing Record 507 | The city name is awbari
# Processing Record 508 | The city name is mikuni
# Processing Record 509 | The city name is opuwo
# Processing Record 510 | The city name is thenzawl
# Processing Record 511 | The city name is flinders
# City not found: azimur  Skipping ...
# Processing Record 513 | The city name is dovers
# City not found: lolua  Skipping ...
# City not found: geresk  Skipping ...
# Processing Record 516 | The city name is apopka
# Processing Record 517 | The city name is kualakapuas
# Processing Record 518 | The city name is salisbury
# Processing Record 519 | The city name is makakilo city
# Processing Record 520 | The city name is gizo
# Processing Record 521 | The city name is khartoum
# Processing Record 522 | The city name is norman wells
# Processing Record 523 | The city name is port hedland
# Processing Record 524 | The city name is fredericton
# Processing Record 525 | The city name is guadalajara
# Processing Record 526 | The city name is beira
# Processing Record 527 | The city name is tepalcingo
# Processing Record 528 | The city name is vossevangen
# Processing Record 529 | The city name is broken hill
# Processing Record 530 | The city name is jaciara
# Processing Record 531 | The city name is chivolo
# Processing Record 532 | The city name is aleksandrov gay
# Processing Record 533 | The city name is saldanha
# Processing Record 534 | The city name is andenes
# Processing Record 535 | The city name is chernyy yar
# Processing Record 536 | The city name is sobrance
# Processing Record 537 | The city name is guiratinga
# Processing Record 538 | The city name is pemangkat
# Processing Record 539 | The city name is lufilufi
# Processing Record 540 | The city name is vila
# Processing Record 541 | The city name is ambanja
# Processing Record 542 | The city name is mao
# Processing Record 543 | The city name is bathsheba
# Processing Record 544 | The city name is ucluelet
# Processing Record 545 | The city name is honiara
# Processing Record 546 | The city name is canavieiras
# Processing Record 547 | The city name is orel-izumrud
# Processing Record 548 | The city name is takoradi
# Processing Record 549 | The city name is maraba
# Processing Record 550 | The city name is revelstoke
# City not found: tarudant  Skipping ...
# Processing Record 552 | The city name is te anau
# Processing Record 553 | The city name is yangjiang
# Processing Record 554 | The city name is coihaique
# Processing Record 555 | The city name is pitimbu
# City not found: ruatoria  Skipping ...
# Processing Record 557 | The city name is twin falls
# Processing Record 558 | The city name is kovernino
# Processing Record 559 | The city name is caala
# Processing Record 560 | The city name is tlalnepantla
# Processing Record 561 | The city name is porangatu
# Processing Record 562 | The city name is villa carlos paz
# Processing Record 563 | The city name is nassogne
# Processing Record 564 | The city name is hvolsvollur
# Processing Record 565 | The city name is bembereke
# Processing Record 566 | The city name is praia
# Processing Record 567 | The city name is tuatapere
# Processing Record 568 | The city name is saint-augustin
# Processing Record 569 | The city name is salo
# Processing Record 570 | The city name is green river
# Processing Record 571 | The city name is vilyuysk
# City not found: malwan  Skipping ...
# Processing Record 573 | The city name is avera
# City not found: bokspits  Skipping ...
# City not found: tubruq  Skipping ...
# Processing Record 576 | The city name is ayr
# Processing Record 577 | The city name is nemuro
# Processing Record 578 | The city name is seymchan
# Processing Record 579 | The city name is coutances
# Processing Record 580 | The city name is hailar
# Processing Record 581 | The city name is sungaipenuh
# Processing Record 582 | The city name is sharjah
# Processing Record 583 | The city name is venice
# Processing Record 584 | The city name is tarakan
# Processing Record 585 | The city name is pulivendla
# Processing Record 586 | The city name is manjacaze
# Processing Record 587 | The city name is camana
# Processing Record 588 | The city name is san cristobal
# Processing Record 589 | The city name is caravelas
# Processing Record 590 | The city name is tobermory
# Processing Record 591 | The city name is persianovskiy
# Processing Record 592 | The city name is sobolevo
# Processing Record 593 | The city name is clyde river
# Processing Record 594 | The city name is oyama
# Processing Record 595 | The city name is manavalakurichi
# City not found: kamenskoye  Skipping ...
# Processing Record 597 | The city name is waingapu
# Processing Record 598 | The city name is taltal
# Processing Record 599 | The city name is kimbe
# City not found: babanusah  Skipping ...
# Processing Record 601 | The city name is tazmalt
# Processing Record 602 | The city name is nongstoin
# Processing Record 603 | The city name is kayankulam
# Processing Record 604 | The city name is dawei
# Processing Record 605 | The city name is raseiniai
# Processing Record 606 | The city name is golaghat
# City not found: marcona  Skipping ...
# Processing Record 608 | The city name is elliot lake
# Processing Record 609 | The city name is bela
# Processing Record 610 | The city name is samarai
# Processing Record 611 | The city name is garissa
# Processing Record 612 | The city name is waipawa
# Processing Record 613 | The city name is worland
# Processing Record 614 | The city name is akonolinga
# Processing Record 615 | The city name is port said
# Processing Record 616 | The city name is aksu
# Processing Record 617 | The city name is kenai
# Processing Record 618 | The city name is yulara
# Processing Record 619 | The city name is berlevag
# Processing Record 620 | The city name is waw
# Processing Record 621 | The city name is thinadhoo
# Processing Record 622 | The city name is carballo
# Processing Record 623 | The city name is belaya gora
# Processing Record 624 | The city name is pakokku
# Processing Record 625 | The city name is pahalgam
# Processing Record 626 | The city name is bosaso
# Processing Record 627 | The city name is mecca
# Processing Record 628 | The city name is yaroslavskiy
# City not found: deh rawud  Skipping ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a dictionary from lists
weather_dict = {"City":name,
                "Lat":lat,
                "Lng":lon,
                "Max_Temp":temp_max,
                "Humidity":humidity,
                "Cloudiness":clouds,
                "Wind_Speed":speed,
                "Country":country,
                "Date":dt}

# %%
# create a data frame using the dictionary
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
#                      City    Lat     Lng  Max_Temp  Humidity  Cloudiness  \
# 0                    Chui -33.70  -53.46     47.01        91          99
# 1              Mossamedes -15.20   12.15     65.95        81           0
# 2                    Hilo  19.73 -155.09     78.80        83          90
# 3          Cabo San Lucas  22.89 -109.91     89.01        73           5
# 4                   Vaini -21.20 -175.20     75.20        83          75
# ..                    ...    ...     ...       ...       ...         ...
# 575               Pakokku  21.33   95.10     88.79        53          46
# 576               Pahlgām  34.03   75.33     63.79        64          52
# 577                Bosaso  11.28   49.18     88.70        42          99
# 578  Makkah al Mukarramah  21.43   39.83     86.92        45          86
# 579          Yaroslavskiy  44.17  132.21     77.58        63          53
#
#      Wind_Speed Country        Date
# 0          9.19      UY  1595641523
# 1          4.79      AO  1595641523
# 2          3.36      US  1595641523
# 3         17.22      MX  1595641524
# 4         12.75      TO  1595641524
# ..          ...     ...         ...
# 575        5.73      MM  1595641673
# 576        1.36      IN  1595641673
# 577       21.36      SO  1595641673
# 578        9.80      SA  1595641594
# 579       10.47      RU  1595641673
#
# [580 rows x 9 columns]

# %%
# create csv from dataframe
weather_data.to_csv(r'output_data\raw_weather_data.csv', index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# check if cities have max humidity > 100
weather_data.describe()
# Out:
#               Lat         Lng    Max_Temp    Humidity  Cloudiness  Wind_Speed  \
# count  580.000000  580.000000  580.000000  580.000000  580.000000  580.000000
# mean    19.615362   20.999069   69.140448   70.820690   47.856897    7.647121
# std     32.929404   90.319633   13.039101   19.638677   39.518456    5.180945
# min    -54.800000 -175.200000   32.000000   10.000000    0.000000    0.130000
# 25%     -7.505000  -55.925000   59.000000   62.000000    1.000000    3.685000
# 50%     22.830000   24.700000   70.905000   76.000000   44.000000    6.555000
# 75%     47.677500  100.352500   78.800000   85.000000   90.000000   10.290000
# max     78.220000  179.320000  101.520000  100.000000  100.000000   32.210000
#
#                Date
# count  5.800000e+02
# mean   1.595642e+09
# std    8.609062e+01
# min    1.595641e+09
# 25%    1.595642e+09
# 50%    1.595642e+09
# 75%    1.595642e+09
# max    1.595642e+09

# %%
clean_city_data = weather_data[weather_data['Humidity']<=100]
clean_city_data.head()
# Out:
#              City    Lat     Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0            Chui -33.70  -53.46     47.01        91          99        9.19
# 1      Mossamedes -15.20   12.15     65.95        81           0        4.79
# 2            Hilo  19.73 -155.09     78.80        83          90        3.36
# 3  Cabo San Lucas  22.89 -109.91     89.01        73           5       17.22
# 4           Vaini -21.20 -175.20     75.20        83          75       12.75
#
#   Country        Date
# 0      UY  1595641523
# 1      AO  1595641523
# 2      US  1595641523
# 3      MX  1595641524
# 4      TO  1595641524

# %%
clean_city_data.count()  #delete
# Out:
# City          580
# Lat           580
# Lng           580
# Max_Temp      580
# Humidity      580
# Cloudiness    580
# Wind_Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
plot_date = date.today().strftime('%m/%d/%Y')
#print(f'Plotted {plot_date}')

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# create a Scatter Plot for temperature vs latitude
x_values = clean_city_data['Lat']
y_values = clean_city_data['Max_Temp']
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black", grid=True)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f"City Latitude vs Max Temperature {plot_date}")
plt.xlim(-65,85) # set the upper and lower limits of our x axis
plt.ylim(20,110) # set the upper and lower limits of our y axis
plt.savefig("Images/Latitude_vs_Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create a Scatter Plot for humidity vs latitude
x_values = clean_city_data['Lat']
y_values = clean_city_data['Humidity']
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs Humidity {plot_date}")
plt.xlim(-85,85) # set the upper and lower limits of our x axis
plt.ylim(0,100) # set the upper and lower limits of our y axis
plt.savefig("Images/Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create a Scatter Plot for cloudiness vs latitude
x_values = clean_city_data['Lat']
y_values = clean_city_data['Cloudiness']
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs Cloudiness {plot_date}")
plt.xlim(-85,85) # set the upper and lower limits of our x axis
plt.ylim(0,100) # set the upper and lower limits of our y axis
plt.savefig("Images/Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create a Scatter Plot for wind speed vs latitude
x_values = clean_city_data['Lat']
y_values = clean_city_data['Wind_Speed']
plt.scatter(x_values,y_values, marker="o", facecolors="blue", edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f"City Latitude vs Wind Speed {plot_date}")
plt.xlim(-85,85) # set the upper and lower limits of our x axis
plt.ylim(0,35) # set the upper and lower limits of our y axis
plt.savefig("Images/Latitude_vs_Wind_Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %%
north_data = clean_city_data[clean_city_data['Lat']>=0]
north_data.head()

# %%
south_data = clean_city_data[clean_city_data['Lat']<0]
south_data.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = north_data['Lat']
y_values = north_data['Max_Temp']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = south_data['Lat']
y_values = south_data['Max_Temp']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = north_data['Lat']
y_values = north_data['Humidity']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = south_data['Lat']
y_values = south_data['Humidity']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = north_data['Lat']
y_values = north_data['Cloudiness']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = south_data['Lat']
y_values = south_data['Cloudiness']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = north_data['Lat']
y_values = north_data['Wind_Speed']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# calculate correlation 
x_values = south_data['Lat']
y_values = south_data['Humidity']

correlation = stats.pearsonr(x_values,y_values)
print(f"The correlation between both factors is {round(correlation[0],4)}")

# create scatter plot with linear regression equation and line
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %%
# The End
